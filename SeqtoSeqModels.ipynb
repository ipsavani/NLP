# %% [markdown]
# # CS 584 Assignment 4 -- Sequence to Sequence Models
#
# #### Name: Pranshu Savani

# %% [markdown]
# ## In this assignment, you are required to follow the steps below:
# 1. Review the lecture slides.
# 2. Implement a Seq2Seq model.
#
# *** Please note that there are many online resources for Seq2Seq models, you are allowed to check them, but DO NOT DIRECTLY COPY from them. Otherwise, you will get ZERO for this assignment. ***

# %%
# !pip install numpy scikit-learn tqdm matplotlib
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download es_core_news_sm
# !pip install sacrebleu

# %% [markdown]
# # 1. Data Process
# In this section, you are required to
# 1. Divide the data into train, validation, and test.
# 2. Preprocess the text data
#
# **Note:** The default dataset is for Spanish-English. Feel free to change other pairs of languages, you can find them [here](http://www.statmt.org/europarl/).

# %%
import numpy as np
from tqdm.notebook import tqdm

def load_data(filepath):
    texts = []
    with open(filepath, 'r', encoding='utf-8') as f:
        count = len(f.readlines())
        
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in tqdm(f, total=count):
            texts.append(line.strip())
            
    return np.array(texts[:20000])

sources = load_data('/content/drive/MyDrive/CS-584-HW4/es-en/text.en')
targets = load_data('/content/drive/MyDrive/CS-584-HW4/es-en/text.es')

print('English sentences size:', sources.shape)
print('Spanish sentences size:', targets.shape)
# Out:
#   0%|          | 0/1965734 [00:00<?, ?it/s]
#   0%|          | 0/1965734 [00:00<?, ?it/s]
# English sentences size: (20000,)
# Spanish sentences size: (20000,)

# %% [markdown]
# ## 1.1 Divide the data into train, validation, and test

# %%
from sklearn.model_selection import train_test_split

source_train, source_test, target_train, target_test = train_test_split(sources, targets, test_size=0.2)
source_train, source_valid, target_train, target_valid = train_test_split(source_train, target_train, test_size=0.2)

train_texts = [(sent_source, sent_target) for sent_source, sent_target in zip(source_train, target_train)]
valid_texts = [(sent_source, sent_target) for sent_source, sent_target in zip(source_valid, target_valid)]
test_texts = [(sent_source, sent_target) for sent_source, sent_target in zip(source_test, target_test)]

print('The size of training set:', len(train_texts))
print('The size of valid set:', len(valid_texts))
print('The size of test set:', len(test_texts))
# Out:
# The size of training set: 12800
# The size of valid set: 3200
# The size of test set: 4000

# %% [markdown]
# ## 1.2 Data preprocessing
# 1. Lowercase the text
# 2. Tokenize the text
# 3. Create vocabulary for the source language and target language, respectively.

# %%
import re
import string
import spacy
from itertools import chain
from unicodedata import normalize, category

nlp_en = spacy.load('en_core_web_sm')
nlp_es = spacy.load('es_core_news_sm')


def tokenize_en(text):
    text = re.sub(r'’', '\'', text) # some of texts contain invalid apostrophes, such as ’
    text = normalize('NFD', text).encode('ascii', 'ignore').decode('UTF-8')
    text = re.sub(r'([.!.?])', r' \1', text)
    text = re.sub(r'[^a-zA-Z-]', r' ', text)
    # tokens = text.lower().strip().split()
    doc = nlp_en(text.lower())
    return [token.text for token in doc]
    # return tokens

def tokenize_es(text):
    doc = nlp_es(text.lower())
    return [token.text for token in doc]

def preprocess(texts, type='en'):
    if type == 'en':
        return [tokenize_en(text) for text in tqdm(texts, desc='en')]
    elif type == 'es':
        return [tokenize_es(text) for text in tqdm(texts, desc='es')]

def generate_vocab(tokenized_texts):
    # Flatten the input to 1d array, Thanks for: 
    # https://stackoverflow.com/questions/29244286/how-to-flatten-a-2d-list-to-1d-without-using-numpy
    vocab = list(chain.from_iterable(tokenized_texts))
    return list(set(vocab))

source_tokens = preprocess(source_train, 'en')
target_tokens = preprocess(target_train, 'es')

source_vocab = generate_vocab(source_tokens)
source_vocab.insert(0, '<start>')
source_vocab.insert(0, '<end>')
source_vocab.insert(0, '<unk>')
source_token2idx = {token: idx for idx, token in enumerate(source_vocab)}

target_vocab = generate_vocab(target_tokens)
target_vocab.insert(0, '<start>')
target_vocab.insert(0, '<end>')
target_vocab.insert(0, '<unk>')


target_token2idx = {token: idx for idx, token in enumerate(target_vocab)}

print('English vocab size:', len(source_vocab))
print('Spanish vocab size:', len(target_vocab))
# Out:
# en:   0%|          | 0/12800 [00:00<?, ?it/s]
# es:   0%|          | 0/12800 [00:00<?, ?it/s]
# English vocab size: 11837
# Spanish vocab size: 19785

# %%
SOS_tok = 2
EOS_tok = 1

# %%
train_set = [([source_token2idx[t] for t in tokenize_en(source)], [target_token2idx[t] for t in tokenize_es(target)]) for source, target in train_texts]
valid_set = [([source_token2idx[t] if t in source_token2idx else 0 for t in tokenize_en(source)], [target_token2idx[t] if t in target_token2idx else 0 for t in tokenize_es(target)]) for source, target in valid_texts]
test_set = [([source_token2idx[t] if t in source_token2idx else 0 for t in tokenize_en(source)], [target_token2idx[t] if t in target_token2idx else 0 for t in tokenize_es(target)]) for source, target in test_texts]

# %% [markdown]
# ## 2. Seq2Seq Model (50 points)
# In this section, you are required to
# 1. Implement a seq2seq model which includes a CNN encoder and an RNN based decoder.
# 2. For each RNN cell, try a simple RNN, LSTM, and GRU.
# 3. Use the validation set to compute the BLEU score and report the best choice.
#
# **Note:** you could use any package you are comfortable with, such as PyTorch and TensorFlow.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import random
import math

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### 2.1 Encoder (25 points)
#
# Try a simple RNN, LSTM, and GRU

# %%
class Encoder(nn.Module):
  def __init__(self, emb_size=256, hid_size=512, p=0.5,fl_cell = 'lstm'):
    super().__init__()
    # create embedding layer
    self.embdng = nn.Embedding(len(source_vocab), emb_size)
    # initialize dropout
    self.p = nn.Dropout(p)
    # initialize encoder neural network
    if fl_cell == 'gru':
      self.rnn = nn.GRU(emb_size, hid_size)
    elif fl_cell == 'rnn':
      self.rnn = nn.RNN(emb_size,hid_size)
    else:
      self.rnn = nn.LSTM(emb_size,hid_size)
    
  def forward(self, src):
    # get embedding for input
    emb = self.dropout(self.embdng(src))
    # pass vectorized embedding to the network
    _, hidden = self.rnn(emb) 
    # hidden = (hidden,cell) if fl_cell = 'lstm'
    # no cell state for GRU or simple RNN
    
    return hidden

# %% [markdown]
# ### 2.2 CNN Encoder (Extra Credit)
#
# A traditional encoder of Seq2Seq models is an RNN-based model, such as RNN, LSTM, or GRU. But CNNs can also be encoders. In this sub-section, you need to implement a CNN encoder for your Seq2Seq model.
#
# **Hint:** We already learned how CNN can be applied to sentence classification tasks. You can simply drop the last layer of TextCNN and output the context vector. Please check this [paper](https://arxiv.org/abs/1510.03820) for details.

# %% [markdown]
# ### 2.3 Decoder (25 points)
# Try a simple RNN, LSTM, and GRU

# %%
class Decoder(nn.Module):
  def __init__(self, emb_size=256, hid_size=512, p=0.5, fl_cell = 'lstm'):
    super().__init__()
    # create embedding layer
    self.embdng = nn.Embedding(len(target_vocab), emb_size)
    # initialize decoder neural network
    if fl_cell == 'gru':
      self.rnn = nn.GRU(emb_size, hid_size)
    elif fl_cell == 'rnn':
      self.rnn = nn.RNN(emb_size, hid_size)
    else:
      self.rnn = nn.LSTM(emb_size, hid_size)
    # output layer of nn
    self.output_lyr = nn.Linear(hid_size , len(target_vocab))
    self.p = nn.Dropout(p)
      
  def forward(self, inp, hid):
    # get input tensors(first input is context vector)
    inp = inp.unsqueeze(0)
    # get embeddings
    emb = self.p(self.embdng(inp))
    # pass context to get new output
    out, hid = self.rnn(emb, hid)
    # get prediction from output layer
    w_p = self.output_lyr(out.squeeze(0))
    return w_p, hid

# %%
class seq2seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        # initialize encoder and decoder
        self.encoder = encoder
        self.decoder = decoder
        self.device = device
    def forward(self, src, targ, tfr = 0.5):
        # initialize tensor to store decoded outputs
        outs = torch.zeros(targ.shape[0], targ.shape[1], len(target_vocab)).to(self.device)
        # get encoder output, final hidden state of encoder is actually the context vecotr we need
        cntxt_vec = self.encoder(src)
        # initialize decoder hidden state with context vector from encoder
        hid = cntxt_vec
        # initialize first input token
        inp = targ[0,:]
        for t in range(1, targ.shape[0]):
            #insert input token embedding and previous hidden state to recieve predictions and new hidden state
            out, hid = self.decoder(inp, hid)
            # greedy decode max probability prediction as candidate for next input
            maxp = out.argmax(1) 
            # use teacher forcing for faster convergence
            if random.random() < tfr:
              inp = targ[t]
            else:
              inp = maxp
            # store predictions to return values
            outs[t] = out
        return outs

# %% [markdown]
# ## 3. Training your Seq2Seq (30 points)
# 1. Implement training process
# 2. Use validation set to calculate BLEU score
# 3. Plot your training loss and validation loss (You could use the code in assignment 1)

# %%
# initialize encoders and decoders for RNN, LSTM and GRU respectively
ncdr_rnn = Encoder(fl_cell='rnn')
dcdr_rnn = Decoder(fl_cell='rnn')
ncdr_lstm = Encoder(fl_cell='lstm')
dcdr_lstm = Decoder(fl_cell='lstm')
ncdr_gru = Encoder(fl_cell='gru')
dcdr_gru = Decoder(fl_cell='gru')
# create seq2seq model object for each cell type
mdl_rnn = seq2seq(ncdr_rnn, dcdr_rnn, device).to(device)
mdl_lstm = seq2seq(ncdr_lstm, dcdr_lstm, device).to(device)
mdl_gru = seq2seq(ncdr_gru, dcdr_gru, device).to(device)

# %%
# these functions convert our data to padded batches with same dimensions to input into the model
def pad_batches(data):
  max_src = 0
  max_trg = 0
  src = []
  trg = []
  for pair in data:
    if len(pair[0])==0 or len(pair[1])==0:
      continue
    if not (pair[0][0]==SOS_tok):
      pair[0].insert(0,SOS_tok)
      pair[1].insert(0,SOS_tok)
    if(len(pair[0])>max_src):
      max_src=len(pair[0])
    if(len(pair[1])>max_trg):
      max_trg = len(pair[1])

  for pair in data:
    if len(pair[0])==0 or len(pair[1])==0:
      continue
    while(len(pair[0])<max_src):
      pair[0].append(EOS_tok)
    src.append(pair[0])
    while(len(pair[1])<max_trg):
      pair[1].append(EOS_tok)
    trg.append(pair[1])
  return src,trg


def get_batches(dataset,batch_size=32):
  bsize = batch_size
  b_srcs = []
  b_trgs = []
  for i in range(int(len(dataset)/bsize)+1):
    start = i*bsize
    end = (i+1)*bsize
    
    if end>len(dataset) and start<=len(dataset):
      end=len(dataset)
    if start==end:
      break
    
    src,trg = pad_batches(dataset[start:end])
    b_srcs.append(src)
    b_trgs.append(trg)
  return (b_srcs,b_trgs)

# %%
# get padded batches for train and valid, defualt batchsize used is 32
t_set = train_set.copy()
v_set = valid_set.copy()
train_batches = get_batches(train_set)
valid_batches = get_batches(valid_set)

# %%
# training the models
import matplotlib.pyplot as plt

models=[]
models.append(mdl_rnn)
models.append(mdl_lstm)
models.append(mdl_gru)
batches = train_batches
vbatches = valid_batches
# define cross entropy loss
criterion = nn.CrossEntropyLoss(ignore_index = EOS_tok)
# loop through each model for training
for mdl_num,model in enumerate(models):
  # initialize optimizer
  optimizer = optim.Adam(model.parameters())
  num_epochs = 1000
  # best_valid_loss = float('inf')

  t_losses = []
  v_losses = []
  loss_every = 0
  for epoch in tqdm(range(num_epochs)):
    model.train()
    # get random batch from train data
    idx = random.randint(0,len(batches[0])-1)
    # convert batch into tensor for nn input
    src_t = torch.tensor(batches[0][idx],dtype=torch.long, device=device)
    trg_t = torch.tensor(batches[1][idx],dtype=torch.long, device=device)
    src = torch.transpose(src_t,0,1)
    trg = torch.transpose(trg_t,0,1)
    optimizer.zero_grad()
    # get output
    pred = model(src, trg)
    dist_size = pred.shape[-1]
    # flatten output to feed into cross entropy
    pred = pred[1:].view(-1, dist_size)
    trg = trg[1:].reshape(-1)
    loss = criterion(pred, trg)
    # update weights
    loss.backward()
    torch.nn.utils.clip_grad_norm_(model.parameters(), 1)
    optimizer.step()
    # record loss per ~200 iterations
    loss_every += loss.item()
    if ((epoch%7==0 or epoch==num_epochs-1) and not(epoch==0)):
      if epoch%7==0:
        train_loss = loss_every/7
      else:
        train_loss = loss_every/((num_epochs-1)%7)
      t_losses.append(train_loss)
      epoch_loss=0
      # calculate validation loss
      # same as train loss but not updating weights via back propogation and step
      model.eval()
      vloss_every = 0
      with torch.no_grad():
        for i in range(len(vbatches[0])):
          vsrc_t = torch.tensor(vbatches[0][i],dtype=torch.long, device=device)
          vtrg_t = torch.tensor(vbatches[1][i],dtype=torch.long, device=device)
          vsrc = torch.transpose(vsrc_t,0,1)
          vtrg = torch.transpose(vtrg_t,0,1)
          vpred = model(vsrc, vtrg, 0)
          vdist_size = vpred.shape[-1]
          vpred = vpred[1:].view(-1, vdist_size)
          vtrg = vtrg[1:].reshape(-1)
          vloss = criterion(vpred, vtrg)
          vloss_every += vloss.item()
      valid_loss = vloss_every/len(vbatches[0])
      v_losses.append(valid_loss)

      print(f'Training Loss: {train_loss:.4f}')
      print(f'Validation Loss: {valid_loss:.4f}')
  # plot valid and train losses
  plt.plot(t_losses,label='train loss')
  plt.plot(v_losses,label='valid loss')
  plt.legend()
  plt.title('cross-entropy loss')
  plt.show()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Training Loss: 9.7224
# Validation Loss: 7.0103
# Training Loss: 6.8973
# Validation Loss: 6.8828
# Training Loss: 6.8457
# Validation Loss: 6.7344
# Training Loss: 6.7311
# Validation Loss: 6.6884
# Training Loss: 6.6953
# Validation Loss: 6.6749
# Training Loss: 6.5745
# Validation Loss: 6.6745
# Training Loss: 6.6069
# Validation Loss: 6.6564
# Training Loss: 6.5803
# Validation Loss: 6.6365
# Training Loss: 6.4390
# Validation Loss: 6.6279
# Training Loss: 6.5464
# Validation Loss: 6.6086
# Training Loss: 6.5722
# Validation Loss: 6.6136
# Training Loss: 6.5084
# Validation Loss: 6.6058
# Training Loss: 6.5300
# Validation Loss: 6.5826
# Training Loss: 6.4996
# Validation Loss: 6.5929
# Training Loss: 6.4226
# Validation Loss: 6.5880
# Training Loss: 6.5124
# Validation Loss: 6.5772
# Training Loss: 6.4070
# Validation Loss: 6.6056
# Training Loss: 6.4138
# Validation Loss: 6.6034
# Training Loss: 6.4655
# Validation Loss: 6.5946
# Training Loss: 6.4286
# Validation Loss: 6.6029
# Training Loss: 6.4880
# Validation Loss: 6.5778
# Training Loss: 6.3550
# Validation Loss: 6.6202
# Training Loss: 6.3892
# Validation Loss: 6.5905
# Training Loss: 6.2895
# Validation Loss: 6.6189
# Training Loss: 6.3097
# Validation Loss: 6.5810
# Training Loss: 6.3446
# Validation Loss: 6.6475
# Training Loss: 6.3554
# Validation Loss: 6.6197
# Training Loss: 6.2847
# Validation Loss: 6.6270
# Training Loss: 6.3411
# Validation Loss: 6.5925
# Training Loss: 6.2952
# Validation Loss: 6.6518
# Training Loss: 6.2993
# Validation Loss: 6.6192
# Training Loss: 6.1984
# Validation Loss: 6.6158
# Training Loss: 6.3472
# Validation Loss: 6.5755
# Training Loss: 6.2950
# Validation Loss: 6.5746
# Training Loss: 6.2430
# Validation Loss: 6.6321
# Training Loss: 6.2849
# Validation Loss: 6.7846
# Training Loss: 6.1769
# Validation Loss: 6.6528
# Training Loss: 6.1592
# Validation Loss: 6.7318
# Training Loss: 6.0133
# Validation Loss: 6.6391
# Training Loss: 6.1794
# Validation Loss: 6.6789
# Training Loss: 6.1452
# Validation Loss: 6.6336
# Training Loss: 6.1664
# Validation Loss: 6.5930
# Training Loss: 6.2253
# Validation Loss: 6.6331
# Training Loss: 6.1477
# Validation Loss: 6.6715
# Training Loss: 6.2189
# Validation Loss: 6.6334
# Training Loss: 6.2573
# Validation Loss: 6.6155
# Training Loss: 6.1605
# Validation Loss: 6.6098
# Training Loss: 6.2979
# Validation Loss: 6.6989
# Training Loss: 6.1693
# Validation Loss: 6.5759
# Training Loss: 6.1032
# Validation Loss: 6.5990
# Training Loss: 6.1005
# Validation Loss: 6.6163
# Training Loss: 6.1038
# Validation Loss: 6.6095
# Training Loss: 6.0913
# Validation Loss: 6.6493
# Training Loss: 6.1055
# Validation Loss: 6.5942
# Training Loss: 6.1386
# Validation Loss: 6.6027
# Training Loss: 6.0716
# Validation Loss: 6.6749
# Training Loss: 5.9925
# Validation Loss: 6.6404
# Training Loss: 6.0894
# Validation Loss: 6.6393
# Training Loss: 6.0321
# Validation Loss: 6.6305
# Training Loss: 6.0724
# Validation Loss: 6.6290
# Training Loss: 5.9928
# Validation Loss: 6.7176
# Training Loss: 6.0086
# Validation Loss: 6.6533
# Training Loss: 6.0487
# Validation Loss: 6.6292
# Training Loss: 6.0144
# Validation Loss: 6.6369
# Training Loss: 6.0615
# Validation Loss: 6.6136
# Training Loss: 6.0567
# Validation Loss: 6.6649
# Training Loss: 5.8990
# Validation Loss: 6.6842
# Training Loss: 6.0042
# Validation Loss: 6.6227
# Training Loss: 5.9589
# Validation Loss: 6.6749
# Training Loss: 6.0594
# Validation Loss: 6.6095
# Training Loss: 6.0090
# Validation Loss: 6.6694
# Training Loss: 5.9492
# Validation Loss: 6.6848
# Training Loss: 5.7119
# Validation Loss: 6.6618
# Training Loss: 5.9495
# Validation Loss: 6.6625
# Training Loss: 5.9995
# Validation Loss: 6.7109
# Training Loss: 5.9639
# Validation Loss: 6.6393
# Training Loss: 6.0460
# Validation Loss: 6.6628
# Training Loss: 5.9193
# Validation Loss: 6.6669
# Training Loss: 5.9559
# Validation Loss: 6.6324
# Training Loss: 6.0203
# Validation Loss: 6.6333
# Training Loss: 5.8247
# Validation Loss: 6.6253
# Training Loss: 6.0112
# Validation Loss: 6.6624
# Training Loss: 6.0797
# Validation Loss: 6.6495
# Training Loss: 5.9258
# Validation Loss: 6.6243
# Training Loss: 5.8986
# Validation Loss: 6.6344
# Training Loss: 5.9243
# Validation Loss: 6.7625
# Training Loss: 5.7234
# Validation Loss: 6.6826
# Training Loss: 6.0766
# Validation Loss: 6.6598
# Training Loss: 5.8265
# Validation Loss: 6.7844
# Training Loss: 5.9898
# Validation Loss: 6.7162
# Training Loss: 5.8405
# Validation Loss: 6.6524
# Training Loss: 5.8772
# Validation Loss: 6.6420
# Training Loss: 5.8663
# Validation Loss: 6.7193
# Training Loss: 6.0981
# Validation Loss: 6.7640
# Training Loss: 5.8327
# Validation Loss: 6.6506
# Training Loss: 5.9032
# Validation Loss: 6.6385
# Training Loss: 6.0111
# Validation Loss: 6.7476
# Training Loss: 5.7779
# Validation Loss: 6.7985
# Training Loss: 5.9561
# Validation Loss: 6.6846
# Training Loss: 5.8970
# Validation Loss: 6.6391
# Training Loss: 5.9276
# Validation Loss: 6.6344
# Training Loss: 5.8752
# Validation Loss: 6.7046
# Training Loss: 5.7791
# Validation Loss: 6.7231
# Training Loss: 5.9564
# Validation Loss: 6.7088
# Training Loss: 6.0656
# Validation Loss: 6.6419
# Training Loss: 5.6352
# Validation Loss: 6.6814
# Training Loss: 5.8106
# Validation Loss: 6.6357
# Training Loss: 5.9852
# Validation Loss: 6.6360
# Training Loss: 5.9609
# Validation Loss: 6.6989
# Training Loss: 5.7991
# Validation Loss: 6.7074
# Training Loss: 5.9410
# Validation Loss: 6.6630
# Training Loss: 5.9451
# Validation Loss: 6.6529
# Training Loss: 5.8878
# Validation Loss: 6.6475
# Training Loss: 6.0010
# Validation Loss: 6.9098
# Training Loss: 5.9383
# Validation Loss: 6.6614
# Training Loss: 5.7477
# Validation Loss: 6.6781
# Training Loss: 5.8086
# Validation Loss: 6.6626
# Training Loss: 5.7924
# Validation Loss: 6.6746
# Training Loss: 5.7599
# Validation Loss: 6.6985
# Training Loss: 5.8467
# Validation Loss: 6.7267
# Training Loss: 5.6829
# Validation Loss: 6.7814
# Training Loss: 5.8217
# Validation Loss: 6.7406
# Training Loss: 6.0039
# Validation Loss: 6.7041
# Training Loss: 5.7883
# Validation Loss: 6.6142
# Training Loss: 5.9464
# Validation Loss: 6.7628
# Training Loss: 5.6763
# Validation Loss: 6.6575
# Training Loss: 5.8156
# Validation Loss: 6.6681
# Training Loss: 5.7760
# Validation Loss: 6.6730
# Training Loss: 5.6699
# Validation Loss: 6.7024
# Training Loss: 5.7324
# Validation Loss: 6.7252
# Training Loss: 5.7885
# Validation Loss: 6.6930
# Training Loss: 5.7163
# Validation Loss: 6.6992
# Training Loss: 5.7769
# Validation Loss: 6.6950
# Training Loss: 5.8139
# Validation Loss: 6.7427
# Training Loss: 5.7000
# Validation Loss: 6.6709
# Training Loss: 5.6702
# Validation Loss: 6.7266
# Training Loss: 5.5397
# Validation Loss: 6.6892
# Training Loss: 5.7852
# Validation Loss: 6.6748
# Training Loss: 5.7827
# Validation Loss: 6.7708
# Training Loss: 5.7713
# Validation Loss: 6.6566
# Training Loss: 5.6004
# Validation Loss: 6.6744
# Training Loss: 5.7832
# Validation Loss: 6.7847
# Training Loss: 5.5888
# Validation Loss: 6.7152
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Training Loss: 10.4935
# Validation Loss: 7.3128
# Training Loss: 6.9616
# Validation Loss: 6.9813
# Training Loss: 6.9042
# Validation Loss: 6.8362
# Training Loss: 6.7117
# Validation Loss: 6.7100
# Training Loss: 6.6181
# Validation Loss: 6.6462
# Training Loss: 6.5481
# Validation Loss: 6.6122
# Training Loss: 6.6128
# Validation Loss: 6.5856
# Training Loss: 6.5874
# Validation Loss: 6.5679
# Training Loss: 6.5612
# Validation Loss: 6.5588
# Training Loss: 6.5211
# Validation Loss: 6.5482
# Training Loss: 6.4637
# Validation Loss: 6.5400
# Training Loss: 6.4695
# Validation Loss: 6.5424
# Training Loss: 6.4749
# Validation Loss: 6.5377
# Training Loss: 6.4021
# Validation Loss: 6.5328
# Training Loss: 6.3373
# Validation Loss: 6.5255
# Training Loss: 6.4691
# Validation Loss: 6.5267
# Training Loss: 6.4396
# Validation Loss: 6.5396
# Training Loss: 6.4386
# Validation Loss: 6.5191
# Training Loss: 6.3854
# Validation Loss: 6.5140
# Training Loss: 6.3874
# Validation Loss: 6.5414
# Training Loss: 6.3998
# Validation Loss: 6.5387
# Training Loss: 6.3022
# Validation Loss: 6.5273
# Training Loss: 6.3688
# Validation Loss: 6.5302
# Training Loss: 6.3927
# Validation Loss: 6.5345
# Training Loss: 6.2920
# Validation Loss: 6.5415
# Training Loss: 6.2236
# Validation Loss: 6.5635
# Training Loss: 6.3347
# Validation Loss: 6.5429
# Training Loss: 6.2602
# Validation Loss: 6.5423
# Training Loss: 6.2110
# Validation Loss: 6.5491
# Training Loss: 6.1590
# Validation Loss: 6.5583
# Training Loss: 6.3980
# Validation Loss: 6.5441
# Training Loss: 6.2518
# Validation Loss: 6.5379
# Training Loss: 6.2228
# Validation Loss: 6.5325
# Training Loss: 6.2393
# Validation Loss: 6.5408
# Training Loss: 6.2190
# Validation Loss: 6.6211
# Training Loss: 6.1676
# Validation Loss: 6.5523
# Training Loss: 6.1082
# Validation Loss: 6.5575
# Training Loss: 6.1875
# Validation Loss: 6.5642
# Training Loss: 6.1513
# Validation Loss: 6.6341
# Training Loss: 6.2528
# Validation Loss: 6.5521
# Training Loss: 6.2212
# Validation Loss: 6.7397
# Training Loss: 6.1194
# Validation Loss: 6.5654
# Training Loss: 6.2967
# Validation Loss: 6.5269
# Training Loss: 6.0880
# Validation Loss: 6.5511
# Training Loss: 6.1132
# Validation Loss: 6.7184
# Training Loss: 6.0844
# Validation Loss: 6.5450
# Training Loss: 6.0499
# Validation Loss: 6.5561
# Training Loss: 6.0589
# Validation Loss: 6.7150
# Training Loss: 6.0543
# Validation Loss: 6.5385
# Training Loss: 6.1448
# Validation Loss: 6.5837
# Training Loss: 6.1492
# Validation Loss: 6.5449
# Training Loss: 5.9938
# Validation Loss: 6.5503
# Training Loss: 5.9710
# Validation Loss: 6.5647
# Training Loss: 6.1525
# Validation Loss: 6.5462
# Training Loss: 6.1109
# Validation Loss: 6.5653
# Training Loss: 6.1721
# Validation Loss: 6.5882
# Training Loss: 6.0687
# Validation Loss: 6.5458
# Training Loss: 6.0286
# Validation Loss: 6.5558
# Training Loss: 6.1894
# Validation Loss: 6.5819
# Training Loss: 6.1114
# Validation Loss: 6.5856
# Training Loss: 6.0909
# Validation Loss: 6.5784
# Training Loss: 5.9316
# Validation Loss: 6.5418
# Training Loss: 6.0364
# Validation Loss: 6.5940
# Training Loss: 6.0581
# Validation Loss: 6.5575
# Training Loss: 6.1486
# Validation Loss: 6.5687
# Training Loss: 6.0841
# Validation Loss: 6.5652
# Training Loss: 6.0350
# Validation Loss: 6.5524
# Training Loss: 5.9878
# Validation Loss: 6.6031
# Training Loss: 6.0837
# Validation Loss: 6.6046
# Training Loss: 5.9668
# Validation Loss: 6.5791
# Training Loss: 6.0028
# Validation Loss: 6.5807
# Training Loss: 5.9851
# Validation Loss: 6.5730
# Training Loss: 6.0178
# Validation Loss: 6.5842
# Training Loss: 6.0665
# Validation Loss: 6.5559
# Training Loss: 5.9071
# Validation Loss: 6.6551
# Training Loss: 6.0314
# Validation Loss: 6.5800
# Training Loss: 6.0424
# Validation Loss: 6.5626
# Training Loss: 5.9300
# Validation Loss: 6.6095
# Training Loss: 6.0166
# Validation Loss: 6.5906
# Training Loss: 6.0314
# Validation Loss: 6.5654
# Training Loss: 5.9495
# Validation Loss: 6.5510
# Training Loss: 5.9936
# Validation Loss: 6.5501
# Training Loss: 5.9365
# Validation Loss: 6.6122
# Training Loss: 5.9903
# Validation Loss: 6.6001
# Training Loss: 6.0733
# Validation Loss: 6.5804
# Training Loss: 5.9478
# Validation Loss: 6.5420
# Training Loss: 5.9152
# Validation Loss: 6.5827
# Training Loss: 5.9521
# Validation Loss: 6.5937
# Training Loss: 5.9276
# Validation Loss: 6.5831
# Training Loss: 5.9428
# Validation Loss: 6.5848
# Training Loss: 5.8762
# Validation Loss: 6.5795
# Training Loss: 5.8508
# Validation Loss: 6.6832
# Training Loss: 5.8762
# Validation Loss: 6.5645
# Training Loss: 6.0082
# Validation Loss: 6.5692
# Training Loss: 5.9880
# Validation Loss: 6.5656
# Training Loss: 5.8700
# Validation Loss: 6.5790
# Training Loss: 5.8850
# Validation Loss: 6.5692
# Training Loss: 5.9254
# Validation Loss: 6.5651
# Training Loss: 5.8218
# Validation Loss: 6.5701
# Training Loss: 5.8368
# Validation Loss: 6.5865
# Training Loss: 5.7801
# Validation Loss: 6.5674
# Training Loss: 5.9572
# Validation Loss: 6.6250
# Training Loss: 5.8694
# Validation Loss: 6.6499
# Training Loss: 5.8862
# Validation Loss: 6.5829
# Training Loss: 5.8374
# Validation Loss: 6.6567
# Training Loss: 5.8969
# Validation Loss: 6.6123
# Training Loss: 5.9345
# Validation Loss: 6.6027
# Training Loss: 5.8198
# Validation Loss: 6.6345
# Training Loss: 5.7824
# Validation Loss: 6.5998
# Training Loss: 5.8426
# Validation Loss: 6.5767
# Training Loss: 5.9960
# Validation Loss: 6.6625
# Training Loss: 5.7555
# Validation Loss: 6.5956
# Training Loss: 5.7529
# Validation Loss: 6.5967
# Training Loss: 5.7756
# Validation Loss: 6.5857
# Training Loss: 5.8485
# Validation Loss: 6.5789
# Training Loss: 5.8294
# Validation Loss: 6.5785
# Training Loss: 5.8547
# Validation Loss: 6.5794
# Training Loss: 5.8958
# Validation Loss: 6.6250
# Training Loss: 5.8104
# Validation Loss: 6.5729
# Training Loss: 5.8655
# Validation Loss: 6.5929
# Training Loss: 5.9052
# Validation Loss: 6.5752
# Training Loss: 5.7510
# Validation Loss: 6.6181
# Training Loss: 5.8647
# Validation Loss: 6.6328
# Training Loss: 5.7701
# Validation Loss: 6.6035
# Training Loss: 5.9212
# Validation Loss: 6.5710
# Training Loss: 5.8130
# Validation Loss: 6.5643
# Training Loss: 5.8698
# Validation Loss: 6.6371
# Training Loss: 5.6942
# Validation Loss: 6.5969
# Training Loss: 5.7941
# Validation Loss: 6.5819
# Training Loss: 5.8883
# Validation Loss: 6.6419
# Training Loss: 5.7286
# Validation Loss: 6.5868
# Training Loss: 5.6793
# Validation Loss: 6.6015
# Training Loss: 5.8187
# Validation Loss: 6.5872
# Training Loss: 5.8329
# Validation Loss: 6.5869
# Training Loss: 5.7266
# Validation Loss: 6.5791
# Training Loss: 5.6871
# Validation Loss: 6.5799
# Training Loss: 5.8746
# Validation Loss: 6.5804
# Training Loss: 5.7351
# Validation Loss: 6.6127
# Training Loss: 5.8360
# Validation Loss: 6.6279
# Training Loss: 5.8102
# Validation Loss: 6.6025
# Training Loss: 5.6004
# Validation Loss: 6.7144
# Training Loss: 5.7972
# Validation Loss: 6.6249
# Training Loss: 5.6725
# Validation Loss: 6.5991
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Training Loss: 10.9883
# Validation Loss: 7.4516
# Training Loss: 7.0568
# Validation Loss: 7.1266
# Training Loss: 7.0468
# Validation Loss: 7.0963
# Training Loss: 7.0587
# Validation Loss: 6.9261
# Training Loss: 6.7830
# Validation Loss: 6.8034
# Training Loss: 6.7261
# Validation Loss: 6.8017
# Training Loss: 6.7082
# Validation Loss: 6.8083
# Training Loss: 6.8105
# Validation Loss: 6.7910
# Training Loss: 6.7186
# Validation Loss: 6.7419
# Training Loss: 6.5841
# Validation Loss: 6.7206
# Training Loss: 6.6477
# Validation Loss: 6.6950
# Training Loss: 6.5997
# Validation Loss: 6.6755
# Training Loss: 6.5070
# Validation Loss: 6.6744
# Training Loss: 6.5735
# Validation Loss: 6.6639
# Training Loss: 6.5138
# Validation Loss: 6.6602
# Training Loss: 6.5777
# Validation Loss: 6.6367
# Training Loss: 6.5673
# Validation Loss: 6.6240
# Training Loss: 6.4110
# Validation Loss: 6.6108
# Training Loss: 6.5620
# Validation Loss: 6.6300
# Training Loss: 6.4033
# Validation Loss: 6.6049
# Training Loss: 6.4386
# Validation Loss: 6.6066
# Training Loss: 6.4132
# Validation Loss: 6.5926
# Training Loss: 6.3559
# Validation Loss: 6.6117
# Training Loss: 6.3577
# Validation Loss: 6.6003
# Training Loss: 6.3615
# Validation Loss: 6.6038
# Training Loss: 6.3991
# Validation Loss: 6.6068
# Training Loss: 6.2587
# Validation Loss: 6.6035
# Training Loss: 6.3459
# Validation Loss: 6.6100
# Training Loss: 6.4647
# Validation Loss: 6.6026
# Training Loss: 6.2690
# Validation Loss: 6.5864
# Training Loss: 6.2955
# Validation Loss: 6.5850
# Training Loss: 6.2988
# Validation Loss: 6.6015
# Training Loss: 6.4304
# Validation Loss: 6.5960
# Training Loss: 6.2566
# Validation Loss: 6.5716
# Training Loss: 6.2185
# Validation Loss: 6.5736
# Training Loss: 6.3082
# Validation Loss: 6.5843
# Training Loss: 6.3526
# Validation Loss: 6.5743
# Training Loss: 6.2577
# Validation Loss: 6.5732
# Training Loss: 6.1779
# Validation Loss: 6.5742
# Training Loss: 6.2900
# Validation Loss: 6.6277
# Training Loss: 6.2008
# Validation Loss: 6.5901
# Training Loss: 6.2170
# Validation Loss: 6.6033
# Training Loss: 6.1886
# Validation Loss: 6.5720
# Training Loss: 6.1702
# Validation Loss: 6.5580
# Training Loss: 6.1904
# Validation Loss: 6.5755
# Training Loss: 6.1569
# Validation Loss: 6.5684
# Training Loss: 6.0008
# Validation Loss: 6.5992
# Training Loss: 6.1415
# Validation Loss: 6.5926
# Training Loss: 6.0835
# Validation Loss: 6.5876
# Training Loss: 5.9789
# Validation Loss: 6.5855
# Training Loss: 6.0411
# Validation Loss: 6.5736
# Training Loss: 6.1362
# Validation Loss: 6.5692
# Training Loss: 6.0750
# Validation Loss: 6.5634
# Training Loss: 5.9315
# Validation Loss: 6.5769
# Training Loss: 6.0226
# Validation Loss: 6.5761
# Training Loss: 6.1282
# Validation Loss: 6.5676
# Training Loss: 6.0236
# Validation Loss: 6.5676
# Training Loss: 6.0555
# Validation Loss: 6.5791
# Training Loss: 6.1022
# Validation Loss: 6.5598
# Training Loss: 6.0883
# Validation Loss: 6.5644
# Training Loss: 6.1064
# Validation Loss: 6.5906
# Training Loss: 6.0985
# Validation Loss: 6.5517
# Training Loss: 6.0256
# Validation Loss: 6.5669
# Training Loss: 6.0107
# Validation Loss: 6.5510
# Training Loss: 6.0146
# Validation Loss: 6.5554
# Training Loss: 6.0840
# Validation Loss: 6.5509
# Training Loss: 6.0529
# Validation Loss: 6.5560
# Training Loss: 5.9660
# Validation Loss: 6.5900
# Training Loss: 5.8506
# Validation Loss: 6.5553
# Training Loss: 5.9904
# Validation Loss: 6.5508
# Training Loss: 5.9457
# Validation Loss: 6.5704
# Training Loss: 6.0682
# Validation Loss: 6.5447
# Training Loss: 6.0378
# Validation Loss: 6.5291
# Training Loss: 5.9394
# Validation Loss: 6.5399
# Training Loss: 6.0581
# Validation Loss: 6.5586
# Training Loss: 5.9160
# Validation Loss: 6.5247
# Training Loss: 6.0307
# Validation Loss: 6.5418
# Training Loss: 5.9647
# Validation Loss: 6.5440
# Training Loss: 5.9278
# Validation Loss: 6.5433
# Training Loss: 5.9304
# Validation Loss: 6.5816
# Training Loss: 5.9361
# Validation Loss: 6.5394
# Training Loss: 5.9300
# Validation Loss: 6.5247
# Training Loss: 5.9783
# Validation Loss: 6.5324
# Training Loss: 5.8306
# Validation Loss: 6.5725
# Training Loss: 5.9860
# Validation Loss: 6.5287
# Training Loss: 5.9716
# Validation Loss: 6.5408
# Training Loss: 5.9072
# Validation Loss: 6.5739
# Training Loss: 5.8765
# Validation Loss: 6.5133
# Training Loss: 5.7904
# Validation Loss: 6.5336
# Training Loss: 5.7541
# Validation Loss: 6.5763
# Training Loss: 5.8575
# Validation Loss: 6.5627
# Training Loss: 5.8859
# Validation Loss: 6.5226
# Training Loss: 5.7061
# Validation Loss: 6.5327
# Training Loss: 5.8653
# Validation Loss: 6.5877
# Training Loss: 5.7517
# Validation Loss: 6.5750
# Training Loss: 5.8659
# Validation Loss: 6.5448
# Training Loss: 5.7845
# Validation Loss: 6.5706
# Training Loss: 5.9130
# Validation Loss: 6.6437
# Training Loss: 5.9510
# Validation Loss: 6.6124
# Training Loss: 5.8471
# Validation Loss: 6.5563
# Training Loss: 5.9396
# Validation Loss: 6.5383
# Training Loss: 5.8212
# Validation Loss: 6.5240
# Training Loss: 5.8467
# Validation Loss: 6.5434
# Training Loss: 5.7407
# Validation Loss: 6.5623
# Training Loss: 5.7993
# Validation Loss: 6.5434
# Training Loss: 5.7197
# Validation Loss: 6.5494
# Training Loss: 5.7937
# Validation Loss: 6.5436
# Training Loss: 5.8174
# Validation Loss: 6.6028
# Training Loss: 5.7334
# Validation Loss: 6.5641
# Training Loss: 5.9405
# Validation Loss: 6.5457
# Training Loss: 5.6777
# Validation Loss: 6.5291
# Training Loss: 5.7848
# Validation Loss: 6.5412
# Training Loss: 5.7628
# Validation Loss: 6.5335
# Training Loss: 5.6564
# Validation Loss: 6.5465
# Training Loss: 5.8436
# Validation Loss: 6.5734
# Training Loss: 5.8531
# Validation Loss: 6.5800
# Training Loss: 5.7826
# Validation Loss: 6.5404
# Training Loss: 5.7096
# Validation Loss: 6.5312
# Training Loss: 5.7938
# Validation Loss: 6.5376
# Training Loss: 5.7588
# Validation Loss: 6.5433
# Training Loss: 5.6231
# Validation Loss: 6.5404
# Training Loss: 5.7573
# Validation Loss: 6.5761
# Training Loss: 5.7898
# Validation Loss: 6.5566
# Training Loss: 5.6186
# Validation Loss: 6.5501
# Training Loss: 5.4790
# Validation Loss: 6.5460
# Training Loss: 5.7675
# Validation Loss: 6.5579
# Training Loss: 5.7173
# Validation Loss: 6.5411
# Training Loss: 5.6905
# Validation Loss: 6.5385
# Training Loss: 5.7186
# Validation Loss: 6.5468
# Training Loss: 5.7016
# Validation Loss: 6.5361
# Training Loss: 5.6075
# Validation Loss: 6.5567
# Training Loss: 5.7876
# Validation Loss: 6.5575
# Training Loss: 5.6957
# Validation Loss: 6.5639
# Training Loss: 5.7325
# Validation Loss: 6.5296
# Training Loss: 5.5192
# Validation Loss: 6.5558
# Training Loss: 5.6394
# Validation Loss: 6.5482
# Training Loss: 5.6749
# Validation Loss: 6.5492
# Training Loss: 5.5997
# Validation Loss: 6.5514
# Training Loss: 5.7410
# Validation Loss: 6.5839
# Training Loss: 5.7227
# Validation Loss: 6.5700
# Training Loss: 5.5874
# Validation Loss: 6.5578
# Training Loss: 5.7882
# Validation Loss: 6.5234
# Training Loss: 5.4398
# Validation Loss: 6.5461

# %% [markdown]
# ## 4. Evaluation (20 points)
# 1. Calculate the BLEU scores of the best seq2seq model obtained from section 2&3 on the test set.
# 2. Select 20 test examples, For each example, print the translation result of your model along with the ground truth

# %% [markdown]
# ### 4.1 Calculate the BLEU score on test set. (10 points)

# %%
import sacrebleu
def cal_bleu_score(model, dataset, print_pred=False):
    
  model.eval()
  with torch.no_grad():
    dec_sents = []
    trg_sents = []
    src_sents = []
    for pair in dataset:
      if((len(pair[1])==0) or (len(pair[0])==0)):
        continue
      if not pair[0][-1]==EOS_tok:
        pair[0].append(EOS_tok)
        pair[0].insert(0,SOS_tok)
        pair[1].append(EOS_tok)
        pair[1].insert(0,SOS_tok)
      src = torch.tensor(pair[0], dtype=torch.long, device=device).view(-1, 1)
      trg = torch.tensor(pair[1], dtype=torch.long, device=device).view(-1, 1)
      preds = model(src, trg, 0) 
      dist_size = preds.shape[-1]
      preds = preds[1:].view(-1, dist_size)
      src = src[1:].reshape(1,-1)
      key_list = list(target_token2idx.keys())
      skey_list = list(source_token2idx.keys())
      # val_list = list(target_token2idx.values())
      decoded_words = ''
      trg_wrds = ''
      src_wrds = ''
      for i in range(len(preds)):
        pred_idx = preds[i].topk(1)
        if not (pred_idx[1].item()==EOS_tok):
          decoded_words=decoded_words+key_list[pred_idx[1].item()]+' '
        if i<len(pair[1]):
          if not(pair[1][i]==EOS_tok) and  not(pair[1][i]==SOS_tok):
            trg_wrds=trg_wrds+key_list[pair[1][i]]+' '
        if(i<len(pair[0])):
          if not(pair[1][i]==SOS_tok) and not(pair[0][i]==EOS_tok):
            src_wrds=src_wrds+skey_list[pair[0][i]]+' '
      if not (trg_wrds==''):# and not(src_wrds==''):
        dec_sents.append(decoded_words)
        trg_sents.append(trg_wrds)
        src_sents.append(src_wrds)
    if(print_pred):
      for i in range(20):
        print('English              :  ' + src_sents[i])
        print('ground-truth spanish :  ' + trg_sents[i])
        print('predicted spanish    :  ' + dec_sents[i])
        
      
  return sacrebleu.corpus_bleu(dec_sents,trg_sents).score

# %%
bs_val_rnn = cal_bleu_score(mdl_rnn, valid_set)
bs_val_lstm = cal_bleu_score(mdl_lstm, valid_set)
bs_val_gru = cal_bleu_score(mdl_gru, valid_set)

print('valid set BLEU scores :')
print(f' RNN  : {bs_val_rnn:4f}')
print(f' LSTM : {bs_val_lstm:4f}')
print(f' GRU  : {bs_val_gru:4f}')
# Out:
#  Valid set BLEU Scores :
#  RNN  : 0.239300
#  LSTM : 0.243800
#  GRU  : 0.289900

# %%
# best model is GRU
bs_test = cal_bleu_score(mdl_gru, test_set)

print(f'best model BLEU for test data: {bs_test:4f}')
# Out:
# best model BLEU for test data: 0.394800

# %% [markdown]
# ### 4.2 Translate 20 test exmaples. (10 points)

# %%
bleu_sc_test = cal_bleu_score(mdl_gru, test_set, print_pred=True)
# Out:
# English              :  they can be the <unk> for a while only by means of a drop in quality for their customers and employees
# ground-truth spanish :  la única manera que tienen de ser las más <unk> durante algún tiempo es a base de pérdida de calidad para los clientes y el personal .
# predicted spanish    :  la de de de de de de de de de de de de de de de de de de de de de de de de de de de
# English              :  madam president   the best tribute that my group and this house can pay to fernando buesa is to take on board his vision   as a european   of the basque country   spain and europe
# ground-truth spanish :  si me permite , señora presidenta , creo que el mejor homenaje que pueden rendir mi grupo y esta asamblea a fernando buesa es recoger lo que él decía , como europeo , sobre su visión del país vasco , de españa y de europa .
# predicted spanish    :  señor presidente , señor presidente , la comisión , la comisión de la de de la de de la de de la de de la de de la de de la de de la de de la de de la de de la de de la de
# English              :  the dipecho agenda includes south - east asia   central america and the caribbean
# ground-truth spanish :  en la agenda de dipecho están el sudeste asiático , américa central y el caribe .
# predicted spanish    :  de la de de de de de de de de de de de de de de de
# English              :  everyone understands that there is concern about this today   but i would not like our demand to be regarded as selectively applicable
# ground-truth spanish :  todo el mundo comprende que hoy nos <unk> de ello , pero yo no querría que nuestra exigencia se <unk> como selectiva .
# predicted spanish    :  en que , , , , , que , que la de de de de de de de de de de de de de
# English              :    sv   we consider that the report contains many practical proposals   which we support   but we are very critical of the convergence approach which <unk> the report
# ground-truth spanish :  ( sv ) opinamos que el informe contiene muchas propuestas prácticas buenas , a las que damos nuestro apoyo , pero somos muy críticos respecto a la perspectiva de convergencia que caracteriza al informe .
# predicted spanish    :  en que , , , , que , que la de de de de de de de de de de de de de de de de de de de de de de de de de de
# English              :  i have received    motions for resolutions pursuant to rule
# ground-truth spanish :  he recibido 5 propuestas de resolución , de conformidad con el apartado 2 del artículo 42 del reglamento .
# predicted spanish    :  creo que , , , que , que la de de de de de de de de de de de
# English              :
# ground-truth spanish :  .
# predicted spanish    :  pausa y
# English              :  you will <unk> and hypocritically use austria as a convenient threat to further <unk> the member states of any real powers in the construction of the european union
# ground-truth spanish :  se <unk> usted de austria para <unk> un poco más todavía a los estados de los verdaderos poderes en la construcción de la unión europea , con cinismo , con hipocresía , pero se <unk> de austria como de un <unk> bastante cómodo .
# predicted spanish    :  en que , la de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de
# English              :  mrs banotti apparently promised to write a letter explaining why permission was withdrawn but so far no letter has been received
# ground-truth spanish :  la sra . banotti prometió , al parecer , escribir una carta <unk> los motivos de dicha retirada , pero hasta el momento no se ha recibido ninguna carta .
# predicted spanish    :  en que , , , , que , que la de de de de de de de de de de de de de de de de de de de de de
# English              :  we do not consider that amendments nos    and     add anything to the
# ground-truth spanish :  opinamos que las enmiendas 2 y 14 no aportan nada a la directiva .
# predicted spanish    :  la de de de de de de de de de de de de de de
# English              :  mr solana   the war in kosovo and the continuing crisis   have served to reveal a european public opinion that is aware that defending the fundamental values that gave rise to the european union   throughout the world   should no longer continue to rest solely on the shoulders of the president of the united states of america and that the time has come to share the burden   which our american friends have constantly been demanding since europe became a world economic power
# ground-truth spanish :  señor alto representante , la guerra de kosovo , la crisis que allí persiste , han sido significativas para una opinión pública europea consciente de que la defensa , en el mundo , de los valores fundamentales que dieron origen a la unión europea no debe seguir estando a cargo solamente del presidente de los estados unidos de <unk> y de que ya es hora de compartir la carga , ese <unk> <unk> , lo que nuestros amigos norteamericanos no han cesado de reclamar desde que europa se ha convertido en potencia económica mundial .
# predicted spanish    :  señor presidente , la que , , que , que , que , que , que , que , que , que , de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de
# English              :  the person i am talking about was a socialist senator who was also a
# ground-truth spanish :  un senador socialista , también parlamentario vasco , cuyo nombre era enrique casas .
# predicted spanish    :  en que , , , , que , que que , que la de de
# English              :  confining oneself to deploring the disaster and expressing sympathy for its victims without applying some restraining measures in order to oblige total to make good all the direct and indirect consequences of the pollution for which it is entirely responsible is tantamount to doing
# ground-truth spanish :  contentarse con lamentar la catástrofe y <unk> a sus víctimas , sin tomar medidas de coacción para obligar a total a reparar todas las consecuencias directas e indirectas de una contaminación de la que es enteramente responsable , es como no hacer nada .
# predicted spanish    :  la que de la de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de
# English              :  however   there are some amendments which attempt to help the countries of the south   specifically amendment no     which   with regard to the recuperation of costs   also indicates that member states must take into account the social and environmental conditions of the countries when it comes to decision making
# ground-truth spanish :  pero hay algunas enmiendas que intentan ayudar a los países del sur , en concreto la enmienda 43 que , cuando se refiere a la recuperación de costes , indica también que los estados miembros deberán tener en cuenta las condiciones sociales y medioambientales de los países a la hora de tomar decisiones .
# predicted spanish    :  en que , la de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de
# English              :  i will   of course   keep you updated on the reply that mr <unk> is bound to send
# ground-truth spanish :  la mantendré por supuesto al tanto de la respuesta que el sr . <unk> no dejará de <unk> .
# predicted spanish    :  señor presidente , la que , , que , que , que , que , que , que , que
# English              :  there are few of them left and they are up against a very powerful
# ground-truth spanish :  ya son muy pocos y su <unk> es un <unk> económico sumamente <unk> .
# predicted spanish    :  la de de de de de de de de de de de de de de
# English              :  on this occasion we have had six minutes of questions from the floor of the house and we have had     minutes of response by the
# ground-truth spanish :  en esta ocasión ha habido seis minutos de preguntas formuladas por los diputados y 29 minutos de respuestas del comisario , junto con su declaración .
# predicted spanish    :  en que , , , , que , que , que , que , que , que , que , de de de de de de de
# English              :  european postal services
# ground-truth spanish :  servicios postales europeos
# predicted spanish    :  depositar través de la
# English              :  adopting this report would have serious consequences for agriculture in the eu if concentrations of   for example   <unk> and <unk> could not exceed the background values for these substances in the aquatic environment and if a limit of zero were to be established for <unk> in the aquatic environment
# ground-truth spanish :  la aprobación de este informe tendrá graves repercusiones sobre la actividad agraria en la ue si la concentración de , por ejemplo , <unk> y <unk> no puede <unk> los valores de fondo fijados para estas sustancias en el agua y si se quiere establecer un valor límite de 0 para la presencia de <unk> en el agua .
# predicted spanish    :  en que , , la de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de
# English              :  as for the eu   s responsibility   the rights of children must be recognised in the charter according to the areas in which the union can give added value to the promotion of the social and economic situation and even the citizenship   in its broadest sense   of children
# ground-truth spanish :  por lo que se refiere al cometido de la unión en cuanto tal , creo que los derechos de los niños deben estar reconocidos en la carta , teniendo en cuenta las esferas en las que la unión puede aportar un valor añadido al fomento de la situación social , económica e incluso ciudadana , en el sentido más amplio , de los niños .
# predicted spanish    :  la que de la de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de de
